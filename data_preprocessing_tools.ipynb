# %% [markdown]
# <a href="https://colab.research.google.com/github/girishpatil1992/MachineLearningFromUdemy/blob/main/data_preprocessing_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preprocessing Tools

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
dataset.fillna(np.mean(dataset['Salary']))
# Out:
#    Country           Age        Salary Purchased
# 0   France     44.000000  72000.000000        No
# 1    Spain     27.000000  48000.000000       Yes
# 2  Germany     30.000000  54000.000000        No
# 3    Spain     38.000000  61000.000000        No
# 4  Germany     40.000000  63777.777778       Yes
# 5   France     35.000000  58000.000000       Yes
# 6    Spain  63777.777778  52000.000000        No
# 7   France     48.000000  79000.000000       Yes
# 8  Germany     50.000000  83000.000000        No
# 9   France     37.000000  67000.000000       Yes

# %%
np.mean(dataset['Salary'])
# Out:
# 63777.77777777778

# %%
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# Find percentage of the missing data
total_missing_val = sum(dataset.isnull().sum())
total_count_vals = np.product(dataset.shape)
pern_missing_vals = (total_missing_val / total_count_vals) * 100
# Drop perticular column or Row or multiple rows or columns
dataset.drop(['Country', 'Age'], axis=1)
dataset.drop(['Country', 'Age'], axis=0)
# Drop the null column or row
dataset.dropna(axis=0)
dataset.dropna(axis=1)
# Fill Missing Values
dataset.fillna(0)
dataset.fillna(np.mean(dataset['Salary']))
# Out:
# 5.0

# %%
dataset.dropna(axis=0)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
print(X)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]

# %%
print(y)
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8     No
# 9    Yes
# Name: Purchased, dtype: object

# %% [markdown]
# ## Taking care of missing data

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])

# %%
print(X)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 63777.77777777778]
#  ['France' 35.0 58000.0]
#  ['Spain' 38.77777777777778 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]

# %% [markdown]
# ## Encoding categorical data

# %% [markdown]
# ### Encoding the Independent Variable

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)

# %% [markdown]
# ### Encoding the Dependent Variable

# %%
print(y)

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
y_test
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.77459667 -0.57735027  1.29099445 -0.19159184 -1.07812594]
#  [-0.77459667  1.73205081 -0.77459667 -0.01411729 -0.07013168]
#  [ 1.29099445 -0.57735027 -0.77459667  0.56670851  0.63356243]
#  [-0.77459667 -0.57735027  1.29099445 -0.30453019 -0.30786617]
#  [-0.77459667 -0.57735027  1.29099445 -1.90180114 -1.42046362]
#  [ 1.29099445 -0.57735027 -0.77459667  1.14753431  1.23265336]
#  [-0.77459667  1.73205081 -0.77459667  1.43794721  1.57499104]
#  [ 1.29099445 -0.57735027 -0.77459667 -0.74014954 -0.56461943]]

# %%
print(X_test)
# Out:
# [[-0.77459667  1.73205081 -0.77459667 -1.46618179 -0.9069571 ]
#  [ 1.29099445 -0.57735027 -0.77459667 -0.44973664  0.20564034]]
